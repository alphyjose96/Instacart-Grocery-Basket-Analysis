# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Python data types

# %% [markdown]
# ## Step7:Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables

# %%
# Method 1
a=75
b=25
print(a+b)
# Out:
# 100

# %%
# Method 2

a=175
b=75
print(a-b)
# Out:
# 100

# %%
# Method 3

a=75
b=50
c=25
print(a+b-c)
# Out:
# 100

# %% [markdown]
# ## Step 8:Code 2 floating-point variables and divide them by each other.

# %%
# Example 1

a=50.25
b=5.5
print (a/b)
# Out:
# 9.136363636363637

# %% [markdown]
# ## Step 9:Construct a short word made of separate strings

# %%
# Example 1

a='Greet'
b='ings'
a+b
# Out:
# 'Greetings'

# %% [markdown]
# ## Step 10:Construct 2 short sentences made of separate strings.

# %%
# Example 1

a = 'Ready '
b = 'to '
c = 'code'
a+b+c
# Out:
# 'Ready to code'

# %%
# Example 2

a = 'Python '
b = 'programming '
c = 'is '
d = 'fun'
a+b+c+d
# Out:
# 'Python programming is fun'

# %% [markdown]
# ## Bonus Task: Write a command that makes a string appear 100 times

# %%
# Example 1

a = 'Ready to code '
print(a*100)
# Out:
# Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code Ready to code
